# %% [markdown]
# https://github.com/AndreasFischer1985/code-snippets/blob/master/py/LangChain_HuggingFace_examples.py

# %%
# !pip uninstall widgetsnbextension nbdev -y
# Out:
# Found existing installation: widgetsnbextension 4.0.9
# Uninstalling widgetsnbextension-4.0.9:
#   Successfully uninstalled widgetsnbextension-4.0.9
# WARNING: Skipping nbdev as it is not installed.

# %%
# !pip install -Uqq ipywidgets

# %%
# the warnings in the libraries used can get old, do not show them
import warnings
warnings.filterwarnings('ignore')

# %%
from transformers import pipeline
model= pipeline(model="google/flan-t5-large") #'text2text-generation'
model.save_pretrained("flan-t5-large")

# %%
from langchain import PromptTemplate, LLMChain
from langchain.llms import HuggingFacePipeline
llm = HuggingFacePipeline.from_model_id(model_id="flan-t5-large", task="text2text-generation", model_kwargs={"temperature":1e-10})

# %%
llm
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text2text_generation.Text2TextGenerationPipeline object at 0x7f52be6bea60>, model_id='flan-t5-large', model_kwargs={'temperature': 1e-10}, pipeline_kwargs={})

# %%
template = PromptTemplate(input_variables=["input"], template="{input}")
chain = LLMChain(llm=llm, verbose=True, prompt=template)
chain("What is the meaning of life?")
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# What is the meaning of life?
#
# > Finished chain.
# {'input': 'What is the meaning of life?', 'text': 'love'}

# %%
from langchain import PromptTemplate, LLMChain
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
chain = LLMChain(llm=llm, verbose=True, prompt=prompt)
chain("What is the meaning of life?")
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
# Question: What is the meaning of life?
# Answer: Let's think step by step.
#
# > Finished chain.
# {'question': 'What is the meaning of life?',
#  'text': 'The meaning of life is to be happy. Happiness is the result of living a happy'}

# %%
# !pip install -Uqq sentence-transformers

# %%
# https://api.python.langchain.com/en/latest/embeddings/langchain_community.embeddings.huggingface.HuggingFaceEmbeddings.html

from langchain_community.embeddings import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
# !pip install -Uqq chromadb

# %%
from langchain.document_loaders import TextLoader
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.llms.base import LLM
from typing import Optional, List, Mapping, Any
from langchain import PromptTemplate, LLMChain
from langchain.embeddings import HuggingFaceInstructEmbeddings 
from langchain.agents import initialize_agent, Tool

texts=["The meaning of life is to love","The meaning of vacation is to relax","Roses are red.","Hack the planet!"]

db = Chroma.from_texts(texts, hf, collection_name="my-collection", persist_directory="my_collection") #vs. from_documents

template = "Cite one of the following pieces of context as an answer to the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n{context}Question: {question}\n\nAnswer:"
template = PromptTemplate(template=template, input_variables=["context", "question"])  
docsearcher = RetrievalQA.from_chain_type(
llm=llm, 
chain_type="stuff", #stuff, map_reduce, refine, map_rerank
chain_type_kwargs={"prompt": template},
return_source_documents=True,
retriever=db.as_retriever(search_type="similarity",search_kwargs={"k":1})) # similarity, mmr
result, sources = docsearcher.run("What is the meaning of life?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 22
#      15 template = PromptTemplate(template=template, input_variables=["context", "question"])
#      16 docsearcher = RetrievalQA.from_chain_type(
#      17 llm=llm,
#      18 chain_type="stuff", #stuff, map_reduce, refine, map_rerank
#      19 chain_type_kwargs={"prompt": template},
#      20 return_source_documents=True,
#      21 retriever=db.as_retriever(search_type="similarity",search_kwargs={"k":1})) # similarity, mmr
# ---> 22 result, sources = docsearcher.run("What is the meaning of life?")
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain/chains/base.py:533, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     496 """Convenience method for executing chain.
#     497
#     498 The main difference between this method and `Chain.__call__` is that this
#    (...)
#     530         # -> "The temperature in Boise is..."
#     531 """
#     532 # Run at start to make sure this is possible/defined
# --> 533 _output_key = self._run_output_key
#     535 if args and not kwargs:
#     536     if len(args) != 1:
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain/chains/base.py:481, in Chain._run_output_key(self)
#     478 @property
#     479 def _run_output_key(self) -> str:
#     480     if len(self.output_keys) != 1:
# --> 481         raise ValueError(
#     482             f"`run` not supported when there is not exactly "
#     483             f"one output key. Got {self.output_keys}."
#     484         )
#     485     return self.output_keys[0]
#
# ValueError: `run` not supported when there is not exactly one output key. Got ['result', 'source_documents'].

# %%
# ?docsearcher.run
# Out:
# Signature:
# docsearcher.run(
#     *args: Any,
#     callbacks: Union[List[langchain_core.callbacks.base.BaseCallbackHandler], langchain_core.callbacks.base.BaseCallbackManager, NoneType] = None,
#     tags: Optional[List[str]] = None,
#     metadata: Optional[Dict[str, Any]] = None,
#     **kwargs: Any,
# ) -> Any
# Docstring:
# [*Deprecated*]  Convenience method for executing chain.
#
# The main difference between this method and `Chain.__call__` is that this
# method expects inputs to be passed directly in as positional arguments or
# keyword arguments, whereas `Chain.__call__` expects a single input dictionary
# with all the inputs
#
# Args:
#     *args: If the chain expects a single input, it can be passed in as the
#         sole positional argument.
#     callbacks: Callbacks to use for this chain run. These will be called in
#         addition to callbacks passed to the chain during construction, but only
#         these runtime callbacks will propagate to calls to other objects.
#     tags: List of string tags to pass to all callbacks. These will be passed in
#         addition to tags passed to the chain during construction, but only
#         these runtime tags will propagate to calls to other objects.
#     **kwargs: If the chain expects multiple inputs, they can be passed in
#         directly as keyword arguments.
#
# Returns:
#     The chain output.
#
# Example:
#     .. code-block:: python
#
#         # Suppose we have a single-input chain that takes a 'question' string:
#         chain.run("What's the temperature in Boise, Idaho?")
#         # -> "The temperature in Boise is..."
#
#         # Suppose we have a multi-input chain that takes a 'question' string
#         # and 'context' string:
#         question = "What's the temperature in Boise, Idaho?"
#         context = "Weather report for Boise, Idaho on 07/03/23..."
#         chain.run(question=question, context=context)
#         # -> "The temperature in Boise is..."[*Deprecated*] Convenience method for executing chain.
#
# The main difference between this method and `Chain.__call__` is that this
# method expects inputs to be passed directly in as positional arguments or
# keyword arguments, whereas `Chain.__call__` expects a single input dictionary
# with all the inputs
#
# Args:
#     *args: If the chain expects a single input, it can be passed in as the
#         sole positional argument.
#     callbacks: Callbacks to use for this chain run. These will be called in
#         addition to callbacks passed to the chain during construction, but only
#         these runtime callbacks will propagate to calls to other objects.
#     tags: List of string tags to pass to all callbacks. These will be passed in
#         addition to tags passed to the chain during construction, but only
#         these runtime tags will propagate to calls to other objects.
#     **kwargs: If the chain expects multiple inputs, they can be passed in
#         directly as keyword arguments.
#
# Returns:
#     The chain output.
#
# Example:
#     .. code-block:: python
#
#         # Suppose we have a single-input chain that takes a 'question' string:
#         chain.run("What's the temperature in Boise, Idaho?")
#         # -> "The temperature in Boise is..."
#
#         # Suppose we have a multi-input chain that takes a 'question' string
#         # and 'context' string:
#         question = "What's the temperature in Boise, Idaho?"
#         context = "Weather report for Boise, Idaho on 07/03/23..."
#         chain.run(question=question, context=context)
#         # -> "The temperature in Boise is..."
#
# Notes
# -----
# .. deprecated:: 0.1.0
#    Use invoke instead.
# File:      ~/notebooks/venv/lib64/python3.9/site-packages/langchain/chains/base.py
# Type:      method

# %%
# ?Chain
# Out:
# Object `Chain` not found.

# %%
hf
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-mpnet-base-v2', cache_folder=None, model_kwargs={'device': 'cpu'}, encode_kwargs={'normalize_embeddings': False}, multi_process=False)

# %%
hf.embed_query("what is openshift")
# Out:
# [-0.04182109609246254,
#  -0.013159789144992828,
#  0.03801683336496353,
#  -0.029535328969359398,
#  -0.04847255349159241,
#  -0.022125670686364174,
#  -0.0012906419578939676,
#  0.06128718703985214,
#  0.008400006219744682,
#  -0.028410136699676514,
#  0.0005424160044640303,
#  0.006250007078051567,
#  0.02838965319097042,
#  0.040865201503038406,
#  -0.028696080669760704,
#  -0.00023915059864521027,
#  0.041187968105077744,
#  0.004959468264132738,
#  -0.15084506571292877,
#  -0.02498084492981434,
#  -0.010282588191330433,
#  -0.03075416572391987,
#  -0.017620496451854706,
#  0.008729619905352592,
#  0.0691290944814682,
#  -0.02000194974243641,
#  -0.016624964773654938,
#  0.07622281461954117,
#  0.04922495782375336,
#  0.03286007046699524,
#  -0.035471782088279724,
#  0.011489353142678738,
#  0.00887718703597784,
#  0.03045700304210186,
#  1.5997846958271111e-06,
#  -0.006798353511840105,
#  -0.010111760348081589,
#  -0.008459136821329594,
#  0.04957021400332451,
#  -0.02109450288116932,
#  0.011823740787804127,
#  0.013927620835602283,
#  -0.013388078659772873,
#  0.009228130802512169,
#  0.004398065153509378,
#  0.0024847041349858046,
#  -0.025904929265379906,
#  -0.05396786704659462,
#  0.01305138599127531,
#  0.047178614884614944,
#  -0.0029107057489454746,
#  -0.015364016406238079,
#  -0.05939917638897896,
#  0.021916411817073822,
#  -0.02135024406015873,
#  -0.001801851554773748,
#  0.008330375887453556,
#  -0.1115276962518692,
#  -0.027260340750217438,
#  0.007696658372879028,
#  -0.04130186885595322,
#  -0.009994188323616982,
#  0.005530743394047022,
#  -0.030678197741508484,
#  0.09497582167387009,
#  0.001381554058752954,
#  -0.03313997760415077,
#  -0.013662314042448997,
#  0.003417170839384198,
#  0.05760856345295906,
#  -0.08352785557508469,
#  0.004876494407653809,
#  0.009551345370709896,
#  -0.0131453238427639,
#  -0.030033940449357033,
#  0.07954583317041397,
#  -0.01402036752551794,
#  0.04518603906035423,
#  0.011659035459160805,
#  -0.006532501429319382,
#  0.01792236417531967,
#  1.1957637070736382e-05,
#  -0.02226080186665058,
#  0.001510217203758657,
#  -0.03777697682380676,
#  0.031789012253284454,
#  0.01757313311100006,
#  -0.0021250939462333918,
#  0.0629594549536705,
#  -0.04437926411628723,
#  0.0426480770111084,
#  0.006819902453571558,
#  -0.028463849797844887,
#  0.026637721806764603,
#  -0.012081142514944077,
#  -0.0027698620688170195,
#  -0.00455098832026124,
#  -0.03210199251770973,
#  0.004760417155921459,
#   0.01966693066060543,
#   -0.0024386972654610872,
#   0.039497945457696915,
#   0.04772314429283142,
#   -0.0036910560447722673,
#   -0.008954215794801712,
#   0.014895554631948471,
#   -0.03796208277344704,
#   0.04580811783671379,
#   -0.0048919799737632275,
#   -0.0017041651299223304,
#   0.004503571428358555,
#   -0.03966299444437027,
#   8.194626537055856e-35,
#   0.02276376076042652,
#   -0.045424822717905045,
#   0.03843165561556816,
#   0.054897647351026535,
#   -0.02050863765180111,
#   -0.022160375490784645,
#   -0.037481095641851425,
#   -0.00501252431422472,
#   0.040846630930900574,
#   -0.013688374310731888,
#   -0.005696896929293871]]

# %%
texts=["The meaning of life is to love","The meaning of vacation is to relax","Roses are red.","Hack the planet!"]

# %%
db = Chroma.from_texts(texts, hf, collection_name="my-collection") #vs. from_documents

# %%
docsearcher = RetrievalQA.from_chain_type(
  llm=llm, 
  chain_type="stuff", #stuff, map_reduce, refine, map_rerank
  return_source_documents=False,
  retriever=db.as_retriever(search_type="similarity",search_kwargs={"k":1})) # similarity, mmr
docsearcher.run("What is the meaning of life?")
# Out:
# 'to love'

# %% [markdown]
# Embedding is the vectorstore.  Load PDF and get into vectorstore...

# %%
# !wget https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/about/openshift_container_platform-4.14-about-en-us.pdf -O ocp-about.pdf
# Out:
# --2024-01-19 11:33:02--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/about/openshift_container_platform-4.14-about-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.139, 23.33.40.146, 2600:1408:20::6870:eb6b, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘ocp-about.pdf’
#
# ocp-about.pdf           [ <=>                ] 135.71K  --.-KB/s    in 0.1s
#
# 2024-01-19 11:33:04 (1.36 MB/s) - ‘ocp-about.pdf’ saved [138966]

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("./ocp-about.pdf")
pages = loader.load_and_split()

# %%
pages
# Out:
# [Document(page_content='OpenShift Container Platform\n \n4.14\nAbout\nIntroduction to OpenShift Container Platform\nLast Updated: 2024-01-17', metadata={'source': './ocp-about.pdf', 'page': 0}),
#  Document(page_content='OpenShift Container Platform\n \n4.14\n \nAbout\nIntroduction to OpenShift Container Platform', metadata={'source': './ocp-about.pdf', 'page': 2}),
#  Document(page_content='Legal Notice\nCopyright \n©\n 2024 Red Hat, Inc.\nThe text of and illustrations in this document are licensed by Red Hat under a Creative Commons\nAttribution–Share Alike 3.0 Unported license ("CC-BY-SA"). An explanation of CC-BY-SA is\navailable at\nhttp://creativecommons.org/licenses/by-sa/3.0/\n. In accordance with CC-BY-SA, if you distribute this document or an adaptation of it, you must\nprovide the URL for the original version.\nRed Hat, as the licensor of this document, waives the right to enforce, and agrees not to assert,\nSection 4d of CC-BY-SA to the fullest extent permitted by applicable law.\nRed Hat, Red Hat Enterprise Linux, the Shadowman logo, the Red Hat logo, JBoss, OpenShift,\nFedora, the Infinity logo, and RHCE are trademarks of Red Hat, Inc., registered in the United States\nand other countries.\nLinux ®\n is the registered trademark of Linus Torvalds in the United States and other countries.\nJava ®\n is a registered trademark of Oracle and/or its affiliates.\nXFS ®\n is a trademark of Silicon Graphics International Corp. or its subsidiaries in the United States\nand/or other countries.\nMySQL ®\n is a registered trademark of MySQL AB in the United States, the European Union and\nother countries.\nNode.js ®\n is an official trademark of Joyent. Red Hat is not formally related to or endorsed by the\nofficial Joyent Node.js open source or commercial project.\nThe \nOpenStack ®\n Word Mark and OpenStack logo are either registered trademarks/service marks\nor trademarks/service marks of the OpenStack Foundation, in the United States and other\ncountries and are used with the OpenStack Foundation\'s permission. We are not affiliated with,\nendorsed or sponsored by the OpenStack Foundation, or the OpenStack community.\nAll other trademarks are the property of their respective owners.\nAbstract\nThis document provides an overview of the OpenShift Container Platform features.', metadata={'source': './ocp-about.pdf', 'page': 3}),
#  Document(page_content='. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\n. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .\nTable of Contents\nCHAPTER 1. OPENSHIFT CONTAINER PLATFORM 4.14 DOCUMENTATION\n1.1. CLUSTER INSTALLER ACTIVITIES\n1.2. OTHER CLUSTER INSTALLER ACTIVITIES\n1.3. DEVELOPER ACTIVITIES\n1.4. CLUSTER ADMINISTRATOR ACTIVITIES\n1.4.1. Manage cluster components\n1.4.2. Change cluster components\n1.4.3. Monitor the cluster\n1.5. HOSTED CONTROL PLANE ACTIVITIES\nCHAPTER 2. LEARN MORE ABOUT OPENSHIFT CONTAINER PLATFORM\n2.1. ARCHITECT\n2.2. CLUSTER ADMINISTRATOR\n2.3. APPLICATION SITE RELIABILITY ENGINEER (APP SRE)\n2.4. DEVELOPER\n3\n3\n4\n5\n6\n6\n7\n7\n8\n9\n9\n9\n9\n10\nTable of Contents\n1', metadata={'source': './ocp-about.pdf', 'page': 4}),
#  Document(page_content='OpenShift Container Platform 4.14 About\n2', metadata={'source': './ocp-about.pdf', 'page': 5}),
#  Document(page_content='CHAPTER 1. OPENSHIFT CONTAINER PLATFORM 4.14\nDOCUMENTATION\nTable of Contents\nWelcome to the official OpenShift Container Platform 4.14 documentation, where you can learn about\nOpenShift Container Platform and start exploring its features.\nTo navigate the OpenShift Container Platform 4.14 documentation, you can use one of the following\nmethods:\nUse the left navigation bar to browse the documentation.\nSelect the task that interests you from the contents of this Welcome page.\nStart with \nArchitecture\n and \nSecurity and compliance\n. Next, view the \nrelease notes\n.\n1.1. CLUSTER INSTALLER ACTIVITIES\nExplore the following OpenShift Container Platform installation tasks:\nOpenShift Container Platform installation overview\n: Depending on the platform, you can\ninstall OpenShift Container Platform on installer-provisioned or user-provisioned infrastructure.\nThe OpenShift Container Platform installation program provides the flexibility to deploy\nOpenShift Container Platform on a range of different platforms.\nInstall a cluster on Alibaba\n: On Alibaba Cloud, you can install OpenShift Container Platform on\ninstaller-provisioned infrastructure. This is currently a Technology Preview feature only.\nInstall a cluster on AWS\n: On AWS, you can install OpenShift Container Platform on installer-\nprovisioned infrastructure or user-provisioned infrastructure.\nInstall a cluster on Azure\n: On Microsoft Azure, you can install OpenShift Container Platform on\ninstaller-provisioned infrastructure or user-provisioned infrastructure.\nInstall a cluster on Azure Stack Hub\n: On Microsoft Azure Stack Hub, you can install OpenShift\nContainer Platform on installer-provisioned infrastructure or user-provisioned infrastructure.\nInstall a cluster on GCP\n: On Google Cloud Platform (GCP) you can install OpenShift Container\nPlatform on installer-provisioned infrastructure or user-provisioned infrastructure.\nInstall a cluster on IBM Cloud®\n: You can install OpenShift Container Platform on IBM Cloud® on\ninstaller-provisioned infrastructure.\nInstall a cluster on IBM Power® Virtual Server\n: You can install OpenShift Container Platform\non IBM Power® Virtual Server on installer-provisioned infrastructure.\nInstall a cluster on IBM Power®\n: You can install OpenShift Container Platform on IBM Power®\non user-provisioned infrastructure.\nInstall a cluster with z/VM on IBM Z® and IBM® LinuxONE\n: You can install OpenShift\nContainer Platform with z/VM on IBM Z® and IBM® LinuxONE on user-provisioned\ninfrastructure.\nInstall a cluster with RHEL KVM on IBM Z® and IBM® LinuxONE\n: You can install OpenShift\nCHAPTER 1. OPENSHIFT CONTAINER PLATFORM 4.14 DOCUMENTATION\n3', metadata={'source': './ocp-about.pdf', 'page': 6}),
#  Document(page_content='Install a cluster with RHEL KVM on IBM Z® and IBM® LinuxONE\n: You can install OpenShift\nContainer Platform with RHEL KVM on IBM Z® and IBM® LinuxONE on user-provisioned\ninfrastructure.\nInstall a cluster on VMware vSphere\n: On supported versions of VMware vSphere, you can\ninstall OpenShift Container Platform on installer-provisioned infrastructure or user-provisioned\ninfrastructure.\nInstall a cluster on bare metal\n: On bare metal, you can install OpenShift Container Platform on\ninstaller-provisioned infrastructure or user-provisioned infrastructure. If none of the available\nplatform and cloud provider deployment options meet your needs, consider using the bare metal\nuser-provisioned infrastructure route.\nInstall a cluster on Red Hat OpenStack Platform (RHOSP)\n: On RHOSP, you can install\nOpenShift Container Platform on installer-provisioned infrastructure or user-provisioned\ninfrastructure.\nInstall a cluster on Nutanix\n: On Nutanix, you can install a cluster on your OpenShift Container\nPlatform on installer-provisioned infrastructure.\n1.2. OTHER CLUSTER INSTALLER ACTIVITIES\nInstall a cluster in a restricted network\n: If your cluster uses user-provisioned infrastructure on\nAWS\n, \nGCP\n, \nvSphere\n, \nIBM Z® and IBM® LinuxONE with z/VM\n, \nIBM Z® and IBM® LinuxONE with\nRHEL KVM\n, \nIBM Power®\n, or \nbare metal\n and the cluster does not have full access to the internet,\nyou must mirror the OpenShift Container Platform installation images. To do this action, use\none of the following methods, so that you can install a cluster in a restricted network.\nMirroring images for a disconnected installation\nMirroring images for a disconnected installation by using the oc-mirror plug-in\nInstall a cluster in an existing network\n: If you use an existing Virtual Private Cloud (VPC) in\nAWS\n or \nGCP\n or an existing \nVNet\n on Microsoft Azure, you can install a cluster. Also consider\nInstalling a cluster on GCP into a shared VPC\nInstall a private cluster\n: If your cluster does not require external internet access, you can install\na private cluster on \nAWS\n, \nAzure\n, \nGCP\n, or \nIBM Cloud®\n. Internet access is still required to access\nthe cloud APIs and installation media.\nCheck installation logs\n: Access installation logs to evaluate issues that occur during OpenShift\nContainer Platform installation.\nAccess OpenShift Container Platform\n: Use credentials output at the end of the installation\nprocess to log in to the OpenShift Container Platform cluster from the command line or web\nconsole.\nInstall Red Hat OpenShift Data Foundation\n: You can install Red Hat OpenShift Data\nFoundation as an Operator to provide highly integrated and simplified persistent storage\nmanagement for containers.\nRed Hat Enterprise Linux CoreOS (RHCOS) image layering\n: As a post-installation task, you\ncan add new images on top of the base RHCOS image. This layering does not modify the base\nRHCOS image. Instead, the layering creates a custom layered image that includes all RHCOS\nfunctions and adds additional functions to specific nodes in the cluster.\nOpenShift Container Platform 4.14 About\n4', metadata={'source': './ocp-about.pdf', 'page': 7}),
#  Document(page_content='1.3. DEVELOPER ACTIVITIES\nDevelop and deploy containerized applications with OpenShift Container Platform. OpenShift Container\nPlatform is a platform for developing and deploying containerized applications. Read the following\nOpenShift Container Platform documentation, so that you can better understand OpenShift Container\nPlatform functions:\nUnderstand OpenShift Container Platform development\n: Learn the different types of\ncontainerized applications, from simple containers to advanced Kubernetes deployments and\nOperators.\nWork with projects\n: Create projects from the OpenShift Container Platform web console or\nOpenShift CLI (\noc\n) to organize and share the software you develop.\nCreating applications using the Developer perspective\n: Use the \nDeveloper\n perspective in the\nOpenShift Container Platform web console to easily create and deploy applications.\nViewing application composition using the Topology view\n: Use the \nTopology\n view to visually\ninteract with your applications, monitor status, connect and group components, and modify your\ncode base.\nUnderstanding Service Binding Operator\n: With the Service Binding Operator, an application\ndeveloper can bind workloads with Operator-managed backing services by automatically\ncollecting and sharing binding data with the workloads. The Service Binding Operator improves\nthe development lifecycle with a consistent and declarative service binding method that\nprevents discrepancies in cluster environments.\nCreate CI/CD Pipelines\n: Pipelines are serverless, cloud-native, continuous integration and\ncontinuous deployment systems that run in isolated containers. Pipelines use standard Tekton\ncustom resources to automate deployments and are designed for decentralized teams that\nwork on microservice-based architecture.\nManage your infrastructure and application configurations\n: GitOps is a declarative way to\nimplement continuous deployment for cloud native applications. GitOps defines infrastructure\nand application definitions as code. GitOps uses this code to manage multiple workspaces and\nclusters to simplify the creation of infrastructure and application configurations. GitOps also\nhandles and automates complex deployments at a fast pace, which saves time during\ndeployment and release cycles.\nDeploy Helm charts\n: \nHelm\n is a software package manager that simplifies deployment of\napplications and services to OpenShift Container Platform clusters. Helm uses a packaging\nformat called \ncharts\n. A Helm chart is a collection of files that describes the OpenShift Container\nPlatform resources.\nUnderstand image builds\n: Choose from different build strategies (Docker, S2I, custom, and\npipeline) that can include different kinds of source materials, such as Git repositories, local\nbinary inputs, and external artifacts. You can follow examples of build types from basic builds to\nadvanced builds.\nCreate container images\n: A container image is the most basic building block in OpenShift\nContainer Platform and Kubernetes applications. By defining image streams, you can gather\nmultiple versions of an image in one place as you continue to develop the image stream. With\nS2I containers, you can insert your source code into a base container. The base container is\nconfigured to run code of a particular type, such as Ruby, Node.js, or Python.\nCreate deployments\n: Use \nDeployment\n and \nDeploymentConfig\n objects to exert fine-grained\nCHAPTER 1. OPENSHIFT CONTAINER PLATFORM 4.14 DOCUMENTATION\n5', metadata={'source': './ocp-about.pdf', 'page': 8}),
#  Document(page_content='Create deployments\n: Use \nDeployment\n and \nDeploymentConfig\n objects to exert fine-grained\nmanagement over applications. \nManage deployments\n by using the \nWorkloads\n page or\nOpenShift CLI (\noc\n). Learn \nrolling, recreate, and custom\n deployment strategies.\nCreate templates\n: Use existing templates or create your own templates that describe how an\napplication is built or deployed. A template can combine images with descriptions, parameters,\nreplicas, exposed ports and other content that defines how an application can be run or built.\nUnderstand Operators\n: Operators are the preferred method for creating on-cluster\napplications for OpenShift Container Platform 4.14. Learn about the Operator Framework and\nhow to deploy applications by using installed Operators into your projects.\nDevelop Operators\n: Operators are the preferred method for creating on-cluster applications\nfor OpenShift Container Platform 4.14. Learn the workflow for building, testing, and deploying\nOperators. You can then create your own Operators based on \nAnsible\n or \nHelm\n, or configure\nbuilt-in Prometheus monitoring\n by using the Operator SDK.\nReference the \nREST API index\n: Learn about OpenShift Container Platform application\nprogramming interface endpoints.\n1.4. CLUSTER ADMINISTRATOR ACTIVITIES\nManage machines, provide services to users, and follow monitoring and logging reports. Read the\nfollowing OpenShift Container Platform documentation, so that you can better understand OpenShift\nContainer Platform functions:\nUnderstand OpenShift Container Platform management\n: Learn about components of the\nOpenShift Container Platform 4.14 control plane. See how OpenShift Container Platform\ncontrol plane and compute nodes are managed and updated through the \nMachine API\n and\nOperators\n.\nEnable cluster capabilities\n: As a cluster administrator, you can enable cluster capabilities that\nwere disabled prior to installation.\n1.4.1. Manage cluster components\nManage machines\n: Manage \ncompute\n and \ncontrol plane\n machines in your cluster with machine\nsets, by \ndeploying health checks\n, and \napplying autoscaling\n.\nManage container registries\n: Each OpenShift Container Platform cluster includes a built-in\ncontainer registry for storing its images. You can also configure a separate \nRed Hat Quay\nregistry to use with OpenShift Container Platform. The \nQuay.io\n website provides a public\ncontainer registry that stores OpenShift Container Platform containers and Operators.\nManage users and groups\n: Add users and groups with different levels of permissions to use or\nmodify clusters.\nManage authentication\n: Learn how user, group, and API authentication works in OpenShift\nContainer Platform. OpenShift Container Platform supports \nmultiple identity providers\n.\nManage \ningress\n, \nAPI server\n, and \nservice\n certificates\n: OpenShift Container Platform creates\ncertificates by default for the Ingress Operator, the API server, and for services needed by\ncomplex middleware applications that require encryption. You might need to change, add, or\nrotate these certificates.\nManage networking\n: The cluster network in OpenShift Container Platform is managed by the\nOpenShift Container Platform 4.14 About\n6', metadata={'source': './ocp-about.pdf', 'page': 9}),
#  Document(page_content='Cluster Network Operator\n (CNO). The CNO uses \niptables\n rules in \nkube-proxy\n to direct traffic\nbetween nodes and pods running on those nodes. The Multus Container Network Interface\nadds the capability to attach \nmultiple network interfaces\n to a pod. By using \nnetwork policy\nfeatures, you can isolate your pods or permit selected traffic.\nManage storage\n: With OpenShift Container Platform, a cluster administrator can configure\npersistent storage by using \nRed Hat OpenShift Data Foundation\n, \nAWS Elastic Block Store\n, \nNFS\n,\niSCSI\n, \nContainer Storage Interface (CSI)\n, and more. You can \nexpand persistent volumes\n,\nconfigure \ndynamic provisioning\n, and use CSI to \nconfigure\n, \nclone\n, and use \nsnapshots\n of\npersistent storage.\nManage Operators\n: Lists of Red Hat, ISV, and community Operators can be reviewed by cluster\nadministrators and \ninstalled on their clusters\n. After you install them, you can \nrun\n, \nupgrade\n, back\nup, or otherwise manage the Operator on your cluster.\nUnderstanding Windows container workloads\n. You can use the Red Hat OpenShift support\nfor Windows Containers feature to run Windows compute nodes in an OpenShift Container\nPlatform cluster. This is possible by using the Red Hat Windows Machine Config Operator\n(WMCO) to install and manage Windows nodes.\n1.4.2. Change cluster components\nUse custom resource definitions (CRDs) to modify the cluster\n: Cluster features implemented\nwith Operators can be modified with CRDs. Learn to \ncreate a CRD\n and \nmanage resources from\nCRDs\n.\nSet resource quotas\n: Choose from CPU, memory, and other system resources to \nset quotas\n.\nPrune and reclaim resources\n: Reclaim space by pruning unneeded Operators, groups,\ndeployments, builds, images, registries, and cron jobs.\nScale\n and \ntune\n clusters\n: Set cluster limits, tune nodes, scale cluster monitoring, and optimize\nnetworking, storage, and routes for your environment.\nUpdate a cluster\n: Use the Cluster Version Operator (CVO) to upgrade your OpenShift\nContainer Platform cluster. If an update is available from the OpenShift Update Service (OSUS),\nyou apply that cluster update from the OpenShift Container Platform \nweb console\n or the\nOpenShift CLI\n (\noc\n).\nUsing the OpenShift Update Service in a disconnected environment\n: Learn about installing\nand managing a local OpenShift Update Service for recommending OpenShift Container\nPlatform updates in disconnected environments.\nImproving cluster stability in high latency environments by using worker latency profiles\n: If\nyour network has latency issues, you can use one of three worker latency profiles to help ensure\nthat your control plane does not accidentally evict pods in case it cannot reach a worker node.\nYou can configure or modify the profile at any time during the life of the cluster.\n1.4.3. Monitor the cluster\nWork with OpenShift Logging\n: Learn about OpenShift Logging and configure different\nOpenShift Logging types, such as Elasticsearch, Fluentd, and Kibana.\nMonitor\n: Learn to \nconfigure the monitoring stack\n. After configuring monitoring, use the web\nconsole to access \nmonitoring dashboards\n. In addition to infrastructure metrics, you can also\nscrape and view metrics for your own services.\nRemote health monitoring\n: OpenShift Container Platform collects anonymized aggregated\nCHAPTER 1. OPENSHIFT CONTAINER PLATFORM 4.14 DOCUMENTATION\n7', metadata={'source': './ocp-about.pdf', 'page': 10}),
#  Document(page_content='Remote health monitoring\n: OpenShift Container Platform collects anonymized aggregated\ninformation about your cluster. By using Telemetry and the Insights Operator, this data is\nreceived by Red Hat and used to improve OpenShift Container Platform. You can view the \ndata\ncollected by remote health monitoring\n.\n1.5. HOSTED CONTROL PLANE ACTIVITIES\nSupport for bare metal and OpenShift Virtualization\n: Hosted control planes for OpenShift\nContainer Platform is now Generally Available on bare metal and OpenShift Virtualization\nplatforms. For more information, see the following documentation:\nConfiguring hosted control plane clusters on bare metal\nManaging hosted control plane clusters on OpenShift Virtualization\nTechnology Preview features\n: Hosted control planes remains available as a Technology\nPreview feature on the Amazon Web Services platform, and is now available as a Technology\nPreview feature on the {ibmzProductName} platform. For more information, see the following\ndocumentation:\nConfiguring the hosting cluster on AWS (Technology Preview)\nConfiguring the hosted cluster on 64-bit x86 bare metal for IBM Z compute nodes\n(Technology Preview)\nEnabling or disabling the hosted control planes feature\n: The hosted control planes feature is\nnow enabled by default.\nOpenShift Container Platform 4.14 About\n8', metadata={'source': './ocp-about.pdf', 'page': 11}),
#  Document(page_content='CHAPTER 2. LEARN MORE ABOUT OPENSHIFT CONTAINER\nPLATFORM\nUse the following sections to find content to help you learn about and use OpenShift Container\nPlatform.\n2.1. ARCHITECT\nLearn about OpenShift\nContainer Platform\nPlan an OpenShift Container\nPlatform deployment\nAdditional resources\nEnterprise Kubernetes with\nOpenShift\nTested platforms\nOpenShift blog\nArchitecture\nSecurity and compliance\nWhat’s new in OpenShift\nContainer Platform\n \nNetworking\nOpenShift Container Platform life\ncycle\n \nBackup and restore\n \n2.2. CLUSTER ADMINISTRATOR\nLearn about OpenShift\nContainer Platform\nDeploy OpenShift\nContainer Platform\nManage OpenShift\nContainer Platform\nAdditional resources\nEnterprise Kubernetes\nwith OpenShift\nInstalling OpenShift\nContainer Platform\nUsing Insights to identify\nissues with your cluster\nGetting Support\nArchitecture\nPost installation\nconfiguration\nLogging\nOpenShift\nKnowledgebase articles\nOpenShift Interactive\nLearning Portal\nNetworking\nMonitoring overview\nOpenShift Container\nPlatform Life Cycle\n \nStorage\n \n \n \nBackup and restore\n \n \n \nUpdating a cluster\n \n \n2.3. APPLICATION SITE RELIABILITY ENGINEER (APP SRE)\nCHAPTER 2. LEARN MORE ABOUT OPENSHIFT CONTAINER PLATFORM\n9', metadata={'source': './ocp-about.pdf', 'page': 12}),
#  Document(page_content='Learn about OpenShift\nContainer Platform\nDeploy and manage applications\nAdditional resources\nOpenShift Interactive Learning\nPortal\nProjects\nGetting Support\nArchitecture\nOperators\nOpenShift Knowledgebase\narticles\n \nLogging\nOpenShift Container Platform\nLife Cycle\n \nBlogs about logging\n \n \nMonitoring\n \n2.4. DEVELOPER\nLearn about application development in OpenShift\nContainer Platform\nDeploy applications\nGetting started with OpenShift for developers\n(interactive tutorial)\nCreating applications\nRed Hat Developers site\nBuilds\nRed Hat OpenShift Dev Spaces (formerly Red Hat\nCodeReady Workspaces)\nOperators\n \nImages\n \nDeveloper-focused CLI\nOpenShift Container Platform 4.14 About\n10', metadata={'source': './ocp-about.pdf', 'page': 13})]

# %%
from langchain_community.vectorstores import FAISS

vectorestore = FAISS.from_documents(pages, hf)

# %%
docsearcher = RetrievalQA.from_chain_type(
  llm=llm, 
  chain_type="stuff", #stuff, map_reduce, refine, map_rerank
  return_source_documents=False,
  retriever=vectorestore.as_retriever(search_type="similarity",search_kwargs={"k":1})) # similarity, mmr
docsearcher.run("what is openshift")
# Out:
# 'OpenShift Container Platform'

# %% [markdown]
# Yay, got something.  Now create a simple UI so I can play around.

# %%
def answer_question(txt):
    return docsearcher.run(txt)

# %%
answer_question("what is ocp")
# Out:
# 'OpenShift Container Platform is a platform for developing and deploying containerized applications'

# %%
# !pip install -Uqq "gradio==3.50"

# %%
import gradio as gr

intf = gr.Interface(fn=answer_question, inputs="textbox", outputs="textbox")
intf.launch(inline=False)
# Out:
# Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# Get some more docs.

# %%
# !mkdir -p openshift/
# !rm -f openshift/*.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/about/openshift_container_platform-4.14-about-en-us.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/getting_started/openshift_container_platform-4.14-getting_started-en-us.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/security_and_compliance/openshift_container_platform-4.14-security_and_compliance-en-us.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/release_notes/openshift_container_platform-4.14-release_notes-en-us.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/architecture/openshift_container_platform-4.14-architecture-en-us.pdf
# !wget -P openshift/ https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/support/openshift_container_platform-4.14-support-en-us.pdf
# Out:
# --2024-01-19 12:47:02--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/about/openshift_container_platform-4.14-about-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.139, 23.33.40.146, 2600:1408:20::6870:eb6b, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-about-en-us.pdf’
#
# openshift_container     [ <=>                ] 135.71K  --.-KB/s    in 0.1s
#
# 2024-01-19 12:47:02 (1.37 MB/s) - ‘openshift/openshift_container_platform-4.14-about-en-us.pdf’ saved [138966]
#
# --2024-01-19 12:47:03--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/getting_started/openshift_container_platform-4.14-getting_started-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.139, 23.33.40.146, 2600:1408:20::6870:eb51, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-getting_started-en-us.pdf’
#
# openshift_container     [  <=>               ]   1.29M  5.72MB/s    in 0.2s
#
# 2024-01-19 12:47:03 (5.72 MB/s) - ‘openshift/openshift_container_platform-4.14-getting_started-en-us.pdf’ saved [1353739]
#
# --2024-01-19 12:47:03--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/security_and_compliance/openshift_container_platform-4.14-security_and_compliance-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.146, 23.33.40.139, 2600:1408:20::6870:eb51, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-security_and_compliance-en-us.pdf’
#
# openshift_container     [  <=>               ]   4.02M  13.1MB/s    in 0.3s
#
# 2024-01-19 12:47:04 (13.1 MB/s) - ‘openshift/openshift_container_platform-4.14-security_and_compliance-en-us.pdf’ saved [4215381]
#
# --2024-01-19 12:47:04--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/release_notes/openshift_container_platform-4.14-release_notes-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.139, 23.33.40.146, 2600:1408:20::6870:eb51, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-release_notes-en-us.pdf’
#
# openshift_container     [ <=>                ] 781.52K  4.41MB/s    in 0.2s
#
# 2024-01-19 12:47:05 (4.41 MB/s) - ‘openshift/openshift_container_platform-4.14-release_notes-en-us.pdf’ saved [800272]
#
# --2024-01-19 12:47:05--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/architecture/openshift_container_platform-4.14-architecture-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.146, 23.33.40.139, 2600:1408:20::6870:eb6b, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-architecture-en-us.pdf’
#
# openshift_container     [  <=>               ]   1.59M  6.47MB/s    in 0.2s
#
# 2024-01-19 12:47:06 (6.47 MB/s) - ‘openshift/openshift_container_platform-4.14-architecture-en-us.pdf’ saved [1665625]
#
# --2024-01-19 12:47:06--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/pdf/support/openshift_container_platform-4.14-support-en-us.pdf
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.146, 23.33.40.139, 2600:1408:20::6870:eb6b, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/pdf]
# Saving to: ‘openshift/openshift_container_platform-4.14-support-en-us.pdf’
#
# openshift_container     [  <=>               ]   1.23M  6.00MB/s    in 0.2s
#
# 2024-01-19 12:47:06 (6.00 MB/s) - ‘openshift/openshift_container_platform-4.14-support-en-us.pdf’ saved [1285128]

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader 
# ?PyPDFDirectoryLoader
# Out:
# Init signature:
# PyPDFDirectoryLoader(
#     path: str,
#     glob: str = '**/[!.]*.pdf',
#     silent_errors: bool = False,
#     load_hidden: bool = False,
#     recursive: bool = False,
#     extract_images: bool = False,
# )
# Docstring:
# Load a directory with `PDF` files using `pypdf` and chunks at character level.
#
# Loader also stores page numbers in metadata.
# File:           ~/notebooks/venv/lib64/python3.9/site-packages/langchain_community/document_loaders/pdf.py
# Type:           ABCMeta
# Subclasses:

# %%
# load all the pdfs

from langchain_community.document_loaders import PyPDFDirectoryLoader

path="openshift/"
loader = PyPDFDirectoryLoader(path)
pages = loader.load_and_split()

# %%
len(pages)
# Out:
# 743

# %%
# https://api.python.langchain.com/en/latest/embeddings/langchain_community.embeddings.huggingface.HuggingFaceEmbeddings.html

from langchain_community.embeddings import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': False}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
from langchain_community.vectorstores import FAISS

vectorestore = FAISS.from_documents(pages, hf)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[83], line 3
#       1 from langchain_community.vectorstores import FAISS
# ----> 3 vectorestore = FAISS.from_documents(pages, hf)
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain_core/vectorstores.py:508, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     506 texts = [d.page_content for d in documents]
#     507 metadatas = [d.metadata for d in documents]
# --> 508 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain_community/vectorstores/faiss.py:913, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     886 @classmethod
#     887 def from_texts(
#     888     cls,
#    (...)
#     893     **kwargs: Any,
#     894 ) -> FAISS:
#     895     """Construct FAISS wrapper from raw documents.
#     896
#     897     This is a user friendly interface that:
#    (...)
#     911             faiss = FAISS.from_texts(texts, embeddings)
#     912     """
# --> 913     embeddings = embedding.embed_documents(texts)
#     914     return cls.__from(
#     915         texts,
#     916         embeddings,
#    (...)
#     920         **kwargs,
#     921     )
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/langchain_community/embeddings/huggingface.py:91, in HuggingFaceEmbeddings.embed_documents(self, texts)
#      89     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#      90 else:
# ---> 91     embeddings = self.client.encode(texts, **self.encode_kwargs)
#      93 return embeddings.tolist()
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/sentence_transformers/SentenceTransformer.py:153, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     150 if device is None:
#     151     device = self._target_device
# --> 153 self.to(device)
#     155 all_embeddings = []
#     156 length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:1160, in Module.to(self, *args, **kwargs)
#    1156         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                     non_blocking, memory_format=convert_to_format)
#    1158     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1160 return self._apply(convert)
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 810 (1 times)]
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:810, in Module._apply(self, fn, recurse)
#     808 if recurse:
#     809     for module in self.children():
# --> 810         module._apply(fn)
#     812 def compute_should_use_set_data(tensor, tensor_applied):
#     813     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     814         # If the new tensor has compatible tensor type as the existing tensor,
#     815         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     820         # global flag to let the user control whether they want the future
#     821         # behavior of overwriting the existing tensor or not.
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:833, in Module._apply(self, fn, recurse)
#     829 # Tensors stored in modules are graph leaves, and we don't want to
#     830 # track autograd history of `param_applied`, so we have to use
#     831 # `with torch.no_grad():`
#     832 with torch.no_grad():
# --> 833     param_applied = fn(param)
#     834 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     835 if should_use_set_data:
#
# File ~/notebooks/venv/lib64/python3.9/site-packages/torch/nn/modules/module.py:1158, in Module.to.<locals>.convert(t)
#    1155 if convert_to_format is not None and t.dim() in (4, 5):
#    1156     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1157                 non_blocking, memory_format=convert_to_format)
# -> 1158 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: PyTorch is not linked with support for opengl devices

# %%
template = "Cite one of the following pieces of context as an answer to the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n{context}Question: {question}\n\nAnswer:"
template = PromptTemplate(template=template, input_variables=["context", "question"])  
docsearcher = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", #stuff, map_reduce, refine, map_rerank
    chain_type_kwargs={"prompt": template},
    return_source_documents=True,
    retriever=vectorestore.as_retriever(search_type="similarity",search_kwargs={"k":1})) # similarity, mmr

# %%
answer = docsearcher.invoke({"query": "what is openshift?"})

# %%
answer
# Out:
# {'query': 'what is openshift?',
#  'result': 'A managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS',
#  'source_documents': [Document(page_content='An approach to writing software. Applications can be separated into the smallest components,\nindependent from each other by using microservices.\nmirror registry\nA registry that holds the mirror of OpenShift Container Platform images.\nmonolithic applications\nApplications that are self-contained, built, and packaged as a single piece.\nnamespaces\nA namespace isolates specific system resources that are visible to all processes. Inside a namespace,\nonly processes that are members of that namespace can see those resources.\nnetworking\nNetwork information of OpenShift Container Platform cluster.\nnode\nA worker machine in the OpenShift Container Platform cluster. A node is either a virtual machine\n(VM) or a physical machine.\nOpenShift Container Platform Update Service (OSUS)\nFor clusters with internet access, Red Hat Enterprise Linux (RHEL) provides over-the-air updates by\nusing an OpenShift Container Platform update service as a hosted service located behind public\nAPIs.\nOpenShift CLI (\noc\n)\nA command line tool to run OpenShift Container Platform commands on the terminal.\nOpenShift Dedicated\nA managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS) and\nGoogle Cloud Platform (GCP). OpenShift Dedicated focuses on building and scaling applications.\nOpenShift image registry\nA registry provided by OpenShift Container Platform to manage images.\nOperator\nThe preferred method of packaging, deploying, and managing a Kubernetes application in an\nOpenShift Container Platform cluster. An Operator takes human operational knowledge and\nencodes it into software that is packaged and shared with customers.\nOperatorHub\nA platform that contains various OpenShift Container Platform Operators to install.\nOperator Lifecycle Manager (OLM)\nOLM helps you to install, update, and manage the lifecycle of Kubernetes native applications. OLM is\nan open source toolkit designed to manage Operators in an effective, automated, and scalable way.\nOSTree\nAn upgrade system for Linux-based operating systems that performs atomic upgrades of complete\nfile system trees. OSTree tracks meaningful changes to the file system tree using an addressable\nobject store, and is designed to complement existing package management systems.\nover-the-air (OTA) updates\nThe OpenShift Container Platform Update Service (OSUS) provides over-the-air updates to\nOpenShift Container Platform, including Red Hat Enterprise Linux CoreOS (RHCOS).\npod\nOne or more containers with shared resources, such as volume and IP addresses, running in your\nOpenShift Container Platform cluster. A pod is the smallest compute unit defined, deployed, and\nmanaged.\nCHAPTER 1. ARCHITECTURE OVERVIEW\n7', metadata={'source': 'openshift/openshift_container_platform-4.14-architecture-en-us.pdf', 'page': 10})]}

# %%
doc=answer['source_documents']
type(doc)
# Out:
# list

# %%
doc[0]
# Out:
# Document(page_content='An approach to writing software. Applications can be separated into the smallest components,\nindependent from each other by using microservices.\nmirror registry\nA registry that holds the mirror of OpenShift Container Platform images.\nmonolithic applications\nApplications that are self-contained, built, and packaged as a single piece.\nnamespaces\nA namespace isolates specific system resources that are visible to all processes. Inside a namespace,\nonly processes that are members of that namespace can see those resources.\nnetworking\nNetwork information of OpenShift Container Platform cluster.\nnode\nA worker machine in the OpenShift Container Platform cluster. A node is either a virtual machine\n(VM) or a physical machine.\nOpenShift Container Platform Update Service (OSUS)\nFor clusters with internet access, Red Hat Enterprise Linux (RHEL) provides over-the-air updates by\nusing an OpenShift Container Platform update service as a hosted service located behind public\nAPIs.\nOpenShift CLI (\noc\n)\nA command line tool to run OpenShift Container Platform commands on the terminal.\nOpenShift Dedicated\nA managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS) and\nGoogle Cloud Platform (GCP). OpenShift Dedicated focuses on building and scaling applications.\nOpenShift image registry\nA registry provided by OpenShift Container Platform to manage images.\nOperator\nThe preferred method of packaging, deploying, and managing a Kubernetes application in an\nOpenShift Container Platform cluster. An Operator takes human operational knowledge and\nencodes it into software that is packaged and shared with customers.\nOperatorHub\nA platform that contains various OpenShift Container Platform Operators to install.\nOperator Lifecycle Manager (OLM)\nOLM helps you to install, update, and manage the lifecycle of Kubernetes native applications. OLM is\nan open source toolkit designed to manage Operators in an effective, automated, and scalable way.\nOSTree\nAn upgrade system for Linux-based operating systems that performs atomic upgrades of complete\nfile system trees. OSTree tracks meaningful changes to the file system tree using an addressable\nobject store, and is designed to complement existing package management systems.\nover-the-air (OTA) updates\nThe OpenShift Container Platform Update Service (OSUS) provides over-the-air updates to\nOpenShift Container Platform, including Red Hat Enterprise Linux CoreOS (RHCOS).\npod\nOne or more containers with shared resources, such as volume and IP addresses, running in your\nOpenShift Container Platform cluster. A pod is the smallest compute unit defined, deployed, and\nmanaged.\nCHAPTER 1. ARCHITECTURE OVERVIEW\n7', metadata={'source': 'openshift/openshift_container_platform-4.14-architecture-en-us.pdf', 'page': 10})

# %%
doc[0].page_content
# Out:
# 'An approach to writing software. Applications can be separated into the smallest components,\nindependent from each other by using microservices.\nmirror registry\nA registry that holds the mirror of OpenShift Container Platform images.\nmonolithic applications\nApplications that are self-contained, built, and packaged as a single piece.\nnamespaces\nA namespace isolates specific system resources that are visible to all processes. Inside a namespace,\nonly processes that are members of that namespace can see those resources.\nnetworking\nNetwork information of OpenShift Container Platform cluster.\nnode\nA worker machine in the OpenShift Container Platform cluster. A node is either a virtual machine\n(VM) or a physical machine.\nOpenShift Container Platform Update Service (OSUS)\nFor clusters with internet access, Red Hat Enterprise Linux (RHEL) provides over-the-air updates by\nusing an OpenShift Container Platform update service as a hosted service located behind public\nAPIs.\nOpenShift CLI (\noc\n)\nA command line tool to run OpenShift Container Platform commands on the terminal.\nOpenShift Dedicated\nA managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS) and\nGoogle Cloud Platform (GCP). OpenShift Dedicated focuses on building and scaling applications.\nOpenShift image registry\nA registry provided by OpenShift Container Platform to manage images.\nOperator\nThe preferred method of packaging, deploying, and managing a Kubernetes application in an\nOpenShift Container Platform cluster. An Operator takes human operational knowledge and\nencodes it into software that is packaged and shared with customers.\nOperatorHub\nA platform that contains various OpenShift Container Platform Operators to install.\nOperator Lifecycle Manager (OLM)\nOLM helps you to install, update, and manage the lifecycle of Kubernetes native applications. OLM is\nan open source toolkit designed to manage Operators in an effective, automated, and scalable way.\nOSTree\nAn upgrade system for Linux-based operating systems that performs atomic upgrades of complete\nfile system trees. OSTree tracks meaningful changes to the file system tree using an addressable\nobject store, and is designed to complement existing package management systems.\nover-the-air (OTA) updates\nThe OpenShift Container Platform Update Service (OSUS) provides over-the-air updates to\nOpenShift Container Platform, including Red Hat Enterprise Linux CoreOS (RHCOS).\npod\nOne or more containers with shared resources, such as volume and IP addresses, running in your\nOpenShift Container Platform cluster. A pod is the smallest compute unit defined, deployed, and\nmanaged.\nCHAPTER 1. ARCHITECTURE OVERVIEW\n7'

# %%
{
        "query": answer['query'],
        "result": answer['result'],
        "metadata": answer['source_documents'][0].metadata,
        "page_content": answer['source_documents'][0].page_content,
    }
# Out:
# {'query': 'what is openshift?',
#  'result': 'A managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS',
#  'metadata': {'source': 'openshift/openshift_container_platform-4.14-architecture-en-us.pdf',
#   'page': 10},
#  'page_content': 'An approach to writing software. Applications can be separated into the smallest components,\nindependent from each other by using microservices.\nmirror registry\nA registry that holds the mirror of OpenShift Container Platform images.\nmonolithic applications\nApplications that are self-contained, built, and packaged as a single piece.\nnamespaces\nA namespace isolates specific system resources that are visible to all processes. Inside a namespace,\nonly processes that are members of that namespace can see those resources.\nnetworking\nNetwork information of OpenShift Container Platform cluster.\nnode\nA worker machine in the OpenShift Container Platform cluster. A node is either a virtual machine\n(VM) or a physical machine.\nOpenShift Container Platform Update Service (OSUS)\nFor clusters with internet access, Red Hat Enterprise Linux (RHEL) provides over-the-air updates by\nusing an OpenShift Container Platform update service as a hosted service located behind public\nAPIs.\nOpenShift CLI (\noc\n)\nA command line tool to run OpenShift Container Platform commands on the terminal.\nOpenShift Dedicated\nA managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS) and\nGoogle Cloud Platform (GCP). OpenShift Dedicated focuses on building and scaling applications.\nOpenShift image registry\nA registry provided by OpenShift Container Platform to manage images.\nOperator\nThe preferred method of packaging, deploying, and managing a Kubernetes application in an\nOpenShift Container Platform cluster. An Operator takes human operational knowledge and\nencodes it into software that is packaged and shared with customers.\nOperatorHub\nA platform that contains various OpenShift Container Platform Operators to install.\nOperator Lifecycle Manager (OLM)\nOLM helps you to install, update, and manage the lifecycle of Kubernetes native applications. OLM is\nan open source toolkit designed to manage Operators in an effective, automated, and scalable way.\nOSTree\nAn upgrade system for Linux-based operating systems that performs atomic upgrades of complete\nfile system trees. OSTree tracks meaningful changes to the file system tree using an addressable\nobject store, and is designed to complement existing package management systems.\nover-the-air (OTA) updates\nThe OpenShift Container Platform Update Service (OSUS) provides over-the-air updates to\nOpenShift Container Platform, including Red Hat Enterprise Linux CoreOS (RHCOS).\npod\nOne or more containers with shared resources, such as volume and IP addresses, running in your\nOpenShift Container Platform cluster. A pod is the smallest compute unit defined, deployed, and\nmanaged.\nCHAPTER 1. ARCHITECTURE OVERVIEW\n7'}

# %%
import json

def answer_question(question):
    # {query,result,source_documents{page_content,metadata{source,page}}}
    answer = docsearcher.invoke({"query": question})
    return {
        "query": answer['query'],
        "result": answer['result'],
        "metadata": answer['source_documents'][0].metadata,
        "page_content": answer['source_documents'][0].page_content,
    }

# %%
answer_question("what is openshift?")
# Out:
# {'query': 'what is openshift?',
#  'result': 'A managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS',
#  'metadata': {'source': 'openshift/openshift_container_platform-4.14-architecture-en-us.pdf',
#   'page': 10},
#  'page_content': 'An approach to writing software. Applications can be separated into the smallest components,\nindependent from each other by using microservices.\nmirror registry\nA registry that holds the mirror of OpenShift Container Platform images.\nmonolithic applications\nApplications that are self-contained, built, and packaged as a single piece.\nnamespaces\nA namespace isolates specific system resources that are visible to all processes. Inside a namespace,\nonly processes that are members of that namespace can see those resources.\nnetworking\nNetwork information of OpenShift Container Platform cluster.\nnode\nA worker machine in the OpenShift Container Platform cluster. A node is either a virtual machine\n(VM) or a physical machine.\nOpenShift Container Platform Update Service (OSUS)\nFor clusters with internet access, Red Hat Enterprise Linux (RHEL) provides over-the-air updates by\nusing an OpenShift Container Platform update service as a hosted service located behind public\nAPIs.\nOpenShift CLI (\noc\n)\nA command line tool to run OpenShift Container Platform commands on the terminal.\nOpenShift Dedicated\nA managed RHEL OpenShift Container Platform offering on Amazon Web Services (AWS) and\nGoogle Cloud Platform (GCP). OpenShift Dedicated focuses on building and scaling applications.\nOpenShift image registry\nA registry provided by OpenShift Container Platform to manage images.\nOperator\nThe preferred method of packaging, deploying, and managing a Kubernetes application in an\nOpenShift Container Platform cluster. An Operator takes human operational knowledge and\nencodes it into software that is packaged and shared with customers.\nOperatorHub\nA platform that contains various OpenShift Container Platform Operators to install.\nOperator Lifecycle Manager (OLM)\nOLM helps you to install, update, and manage the lifecycle of Kubernetes native applications. OLM is\nan open source toolkit designed to manage Operators in an effective, automated, and scalable way.\nOSTree\nAn upgrade system for Linux-based operating systems that performs atomic upgrades of complete\nfile system trees. OSTree tracks meaningful changes to the file system tree using an addressable\nobject store, and is designed to complement existing package management systems.\nover-the-air (OTA) updates\nThe OpenShift Container Platform Update Service (OSUS) provides over-the-air updates to\nOpenShift Container Platform, including Red Hat Enterprise Linux CoreOS (RHCOS).\npod\nOne or more containers with shared resources, such as volume and IP addresses, running in your\nOpenShift Container Platform cluster. A pod is the smallest compute unit defined, deployed, and\nmanaged.\nCHAPTER 1. ARCHITECTURE OVERVIEW\n7'}

# %%
import gradio as gr

intf = gr.Interface(fn=answer_question, inputs="textbox", outputs="textbox")
intf.launch(inline=False)
# Out:
# Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.

# %%
# for cv2, needed to use url loaders
# !pip install -Uqq scikit-build numpy opencv-python unstructured-inference pikepdf

# %%
# !pip install -Uqq cookielib
# Out:
# ERROR: Could not find a version that satisfies the requirement cookielib (from versions: none)
# ERROR: No matching distribution found for cookielib

# %%
# !wget -O index.html "https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14"
# Out:
# --2024-01-19 14:35:23--  https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14
# Resolving access.redhat.com (access.redhat.com)... 23.33.40.139, 23.33.40.146, 2600:1408:20::1722:f082, ...
# Connecting to access.redhat.com (access.redhat.com)|23.33.40.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [  <=>               ] 130.04K   561KB/s    in 0.2s
#
# 2024-01-19 14:35:23 (561 KB/s) - ‘index.html’ saved [133160]

# %%
import re

with open("index.html", "r") as f:
    html = f.read()

urls = []

for x in html.splitlines():
    if "Single-page HTML" in x:
        m = re.match(".*href=\"([^\"]*)\".*", x)
        urls.append(f"https://access.redhat.com{m.groups()[0]}")

urls
# Out:
# ['https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/about',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/getting_started',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/release_notes',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/security_and_compliance',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/architecture',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/support',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/installing',
#  'https://access.redhat.com/documentation/en-us/assisted_installer_for_openshift_container_platform/2024/html-single/installing_openshift_container_platform_with_the_assisted_installer',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/updating_clusters',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/authentication_and_authorization',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/networking',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/registry',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/postinstallation_configuration',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/storage',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/scalability_and_performance',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/migrating_from_version_3_to_4',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/migration_toolkit_for_containers',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/backup_and_restore',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/machine_management',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/web_console',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/hosted_control_planes',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/cli_tools',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/building_applications',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/serverless',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/images',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/nodes',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/operators',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/specialized_hardware_and_driver_enablement',
#  'https://access.redhat.com/documentation/en-us/openshift_sandboxed_containers/1.5/html-single/openshift_sandboxed_containers_release_notes',
#  'https://access.redhat.com/documentation/en-us/openshift_sandboxed_containers/1.5/html-single/openshift_sandboxed_containers_user_guide',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/builds_using_buildconfig',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/jenkins',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/monitoring',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/logging',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/distributed_tracing',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/red_hat_build_of_opentelemetry',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/network_observability',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/virtualization',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/service_mesh',
#  'https://access.redhat.com/documentation/en-us/openshift_container_platform/4.14/html-single/windows_container_support_for_openshift']

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

loader = UnstructuredURLLoader(urls=urls)

pages = loader.load_and_split()
